# %% [markdown]
# # Activity: Hypothesis testing with Python

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# As you've been learning, analysis of variance (commonly called ANOVA) is a group of statistical techniques that test the difference of means among three or more groups. It's a powerful tool for determining whether population means are different across groups and for answering a wide range of business questions.
#
# In this activity, you are a data professional working with historical marketing promotion data. You will use the data to run a one-way ANOVA and a post hoc ANOVA test. Then, you will communicate your results to stakeholders. These experiences will help you make more confident recommendations in a professional setting.
#
# In your dataset, each row corresponds to an independent marketing promotion, where your business uses TV, social media, radio, and influencer promotions to increase sales. You have previously provided insights about how different promotion types affect sales; now stakeholders want to know if sales are significantly different among various TV and influencer promotion types.
#
# To address this request, a one-way ANOVA test will enable you to determine if there is a statistically significant difference in sales among groups. This includes:
# * Using plots and descriptive statistics to select a categorical independent variable
# * Creating and fitting a linear regression model with the selected categorical independent variable
# * Checking model assumptions
# * Performing and interpreting a one-way ANOVA test
# * Comparing pairs of groups using an ANOVA post hoc test
# * Interpreting model outputs and communicating the results to nontechnical stakeholders

# %% [markdown]
# ## **Step 1: Imports**

# %% [markdown]
# Import pandas, pyplot from matplotlib, seaborn, api from statsmodels, ols from statsmodels.formula.api, and pairwise_tukeyhsd from statsmodels.stats.multicomp.

# %%
# Import libraries and packages.

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %% [markdown]
# `Pandas` was used to load the dataset `marketing_sales_data.csv` as `data`, now display the first five rows. The variables in the dataset have been adjusted to suit the objectives of this lab. As shown in this cell, the dataset has been automatically loaded in for you. You do not need to download the .csv file, or provide more code, in order to access the dataset and proceed with this lab. Please continue with this activity by completing the following instructions.

# %%
# RUN THIS CELL TO IMPORT YOUR DATA.

data = pd.read_csv('marketing_sales_data.csv')

# Display the first five rows.

data.head()
# Out:
#        TV      Radio  Social Media Influencer       Sales
# 0     Low   1.218354      1.270444      Micro   90.054222
# 1  Medium  14.949791      0.274451      Macro  222.741668
# 2     Low  10.377258      0.061984       Mega  102.774790
# 3    High  26.469274      7.070945      Micro  328.239378
# 4    High  36.876302      7.618605       Mega  351.807328

# %% [markdown]
# The features in the data are:
# * TV promotion budget (in Low, Medium, and High categories)
# * Social media promotion budget (in millions of dollars)
# * Radio promotion budget (in millions of dollars)
# * Sales (in millions of dollars)
# * Influencer size (in Mega, Macro, Nano, and Micro categories)

# %% [markdown]
# **Question:** Why is it useful to perform exploratory data analysis before constructing a linear regression model?

# %% [markdown]
# To identify the qualities of your dataset in order to assist you in creating meaningful models.

# %% [markdown]
# ## **Step 2: Data exploration**

# %% [markdown]
# First, use a boxplot to determine how `Sales` vary based on the `TV` promotion budget category.

# %%
# Create a boxplot with TV and Sales.

sns.boxplot(data=data, x='TV', y='Sales')

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# There is a function in the `seaborn` library that creates a boxplot showing the distribution of a variable across multiple groups.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# Use the `boxplot()` function from `seaborn`.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
# Use `TV` as the `x` argument, `Sales` as the `y` argument, and `data` as the `data` argument.
#
# </details>

# %% [markdown]
# **Question:** Is there variation in `Sales` based off the `TV` promotion budget?

# %% [markdown]
# Yes, the higher the TV budget, teh more sales.

# %% [markdown]
# Now, use a boxplot to determine how `Sales` vary based on the `Influencer` size category.

# %%
# Create a boxplot with Influencer and Sales.

sns.boxplot(data=data, x='Influencer', y='Sales')

# %% [markdown]
# **Question:** Is there variation in `Sales` based off the `Influencer` size?

# %% [markdown]
# A lot less compared to TV, however you can say there is some variation.

# %% [markdown]
# ### Remove missing data
#
# You may recall from prior labs that this dataset contains rows with missing values. To correct this, drop these rows. Then, confirm the data contains no missing values.

# %%
# Drop rows that contain missing data and update the DataFrame.

data = data.dropna(axis=0)

# Confirm the data contains no missing values.

data.isnull().sum(axis=0)
# Out:
# TV              0
# Radio           0
# Social Media    0
# Influencer      0
# Sales           0
# dtype: int64

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# There is a `pandas` function that removes missing values.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# The `dropna()` function removes missing values from an object (e.g., DataFrame).
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
# Verify the data is updated properly after the rows containing missing data are dropped.
#
# </details>

# %% [markdown]
# ## **Step 3: Model building**

# %% [markdown]
# Fit a linear regression model that predicts `Sales` using one of the independent categorical variables in `data`. Refer to your previous code for defining and fitting a linear regression model.

# %%
# Define the OLS formula.

formula = 'Sales ~ C(TV)'

# Create an OLS model.

OLS = ols(formula = formula, data = data)

# Fit the model.

model = OLS.fit()

# Save the results summary.

results = model.summary()

# Display the model results.

results
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.874
# Model:                            OLS   Adj. R-squared:                  0.874
# Method:                 Least Squares   F-statistic:                     1971.
# Date:                Thu, 28 May 2026   Prob (F-statistic):          8.81e-256
# Time:                        09:21:08   Log-Likelihood:                -2778.9
# No. Observations:                 569   AIC:                             5564.
# Df Residuals:                     566   BIC:                             5577.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Refer to code you've written to fit linear regression models.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# Use the `ols()` function from `statsmodels.formula.api`, which creates a model from a formula and DataFrame, to create an OLS model.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
# Use `C()` around the variable name in the ols formula to indicate a variable is categorical.
#
# Be sure the variable string names exactly match the column names in `data`.
#
# </details>

# %% [markdown]
# **Question:** Which categorical variable did you choose for the model? Why?

# %% [markdown]
# I chose TV, as this had more of an impact on sales.

# %% [markdown]
# ### Check model assumptions

# %% [markdown]
# Now, check the four linear regression assumptions are upheld for your model.

# %% [markdown]
# **Question:** Is the linearity assumption met?

# %% [markdown]
# There are no continuous independent variables, so this is not required.

# %% [markdown]
# The independent observation assumption states that each observation in the dataset is independent. As each marketing promotion (row) is independent from one another, the independence assumption is not violated.

# %% [markdown]
# Next, verify that the normality assumption is upheld for the model.

# %%
# Calculate the residuals.

residuals = model.resid

# Create a histogram with the residuals. 

fig = sns.histplot(residuals)
fig.set_xlabel('Residuals')
fig.set_title('Residuals')

# Create a QQ plot of the residuals.

sm.qqplot(residuals, line='s')
plt.title('QQ Plot')

plt.show()

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Access the residuals from the fit model object.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# Use `model.resid` to get the residuals from a fit model called `model`.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
# For the histogram, pass the residuals as the first argument in the `seaborn` `histplot()` function.
#
# For the QQ-plot, pass the residuals as the first argument in the `statsmodels` `qqplot()` function.
#
# </details>

# %% [markdown]
# **Question:** Is the normality assumption met?

# %% [markdown]
# Technically speaking, it is not fully met due to the shape of the graphs above. However, I will assume the normality assumption is met.

# %% [markdown]
# Now, verify the constant variance (homoscedasticity) assumption is met for this model.

# %%
# Create a scatter plot with the fitted values from the model and the residuals.

fig = sns.scatterplot(model.fittedvalues, y=residuals)

fig.set_xlabel("Fitted Values")
fig.set_ylabel("Residuals")
fig.set_title("Residuals vs Fitted Values")

# Add a line at y = 0 to visualize the variance of residuals above and below 0.

fig.axhline(0)

plt.show()

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Access the fitted values from the model object fit earlier.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# Use `model.fittedvalues` to get the fitted values from the fit model called `model`.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
#
# Call the `scatterplot()` function from the `seaborn` library and pass in the fitted values and residuals.
#
# Add a line to a figure using the `axline()` function.
#
# </details>

# %% [markdown]
# **Question:** Is the constant variance (homoscedasticity) assumption met?

# %% [markdown]
# The assumption is met, as there the residuals are randomly distributed (in each category).

# %% [markdown]
# ## **Step 4: Results and evaluation**

# %% [markdown]
# First, display the OLS regression results.

# %%
# Display the model results summary.

results
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.874
# Model:                            OLS   Adj. R-squared:                  0.874
# Method:                 Least Squares   F-statistic:                     1971.
# Date:                Thu, 28 May 2026   Prob (F-statistic):          8.81e-256
# Time:                        09:21:08   Log-Likelihood:                -2778.9
# No. Observations:                 569   AIC:                             5564.
# Df Residuals:                     566   BIC:                             5577.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %% [markdown]
# **Question:** What is your interpretation of the model's R-squared?

# %% [markdown]
# The R-squared is 0.874, which indicates that 87.4% of the sales are explained by the TV advertising spend. This is a strong relationship.

# %% [markdown]
# **Question:** What is your intepretation of the coefficient estimates? Are the coefficients statistically significant?

# %% [markdown]
# They are statstically significant, as all P-value are below 0.05.

# %% [markdown]
# **Question:** Do you think your model could be improved? Why or why not? How?

# %% [markdown]
# I belive the model could be improved by having the actual TV budgets in the data. This would provide a more accurate result.

# %% [markdown]
# ### Perform a one-way ANOVA test
#
# With the model fit, run a one-way ANOVA test to determine whether there is a statistically significant difference in `Sales` among groups.

# %%
# Create an one-way ANOVA table for the fit model.

sm.stats.anova_lm(model, typ=2)
# Out:
#                 sum_sq     df            F         PR(>F)
# C(TV)     4.052692e+06    2.0  1971.455737  8.805550e-256
# Residual  5.817589e+05  566.0          NaN            NaN

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Review what you've learned about how to perform a one-way ANOVA test.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# There is a function in `statsmodels.api` (i.e. `sm`) that peforms an ANOVA test for a fit linear model.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
# Use the `anova_lm()` function from `sm.stats`. Specify the type of ANOVA test (for example, one-way or two-way), using the `typ` parameter.
#
#
# </details>

# %% [markdown]
# **Question:** What are the null and alternative hypotheses for the ANOVA test?

# %% [markdown]
# The null hypothesis is that there is no difference in sales between the different TV categories. The alternative hypothesis is that there is a difference between the categories.

# %% [markdown]
# **Question:** What is your conclusion from the one-way ANOVA test?

# %% [markdown]
# The F-statistic is very large (1971) and the P-value is very small. There is a statistically significant difference between the different TV categories and sales.

# %% [markdown]
# **Question:** What did the ANOVA test tell you?

# %% [markdown]
# That there is evidence to reject the null hypothesis and believe that there is a difference between the TV promotion categories in terms of sales.

# %% [markdown]
# ### Perform an ANOVA post hoc test
#
# If you have significant results from the one-way ANOVA test, you can apply ANOVA post hoc tests such as the Tukey’s HSD post hoc test.
#
# Run the Tukey’s HSD post hoc test to compare if there is a significant difference between each pair of categories for TV.

# %%
# Perform the Tukey's HSD post hoc test.

HSD = pairwise_tukeyhsd(endog = data['Sales'], groups = data['TV'])
HSD.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Review what you've learned about how to perform a Tukey's HSD post hoc test.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 2</strong></h4></summary>
#
# Use the `pairwise_tukeyhsd()` function from `statsmodels.stats.multicomp`.
#
# </details>

# %% [markdown]
# <details>
# <summary><h4><strong>Hint 3</strong></h4></summary>
#
# The `endog` argument in `pairwise_tukeyhsd` indicates which variable is being compared across groups (i.e., `Sales`). The `groups` argument in `pairwise_tukeyhsd` tells the function which variable holds the group you’re interested in reviewing.
#
# </details>

# %% [markdown]
# **Question:** What is your interpretation of the Tukey HSD test?

# %% [markdown]
# All categories differ from each other. You can reject the null hypothesis for all groups.

# %% [markdown]
# **Question:** What did the post hoc tell you?**

# %% [markdown]
# The post hoc test analysed whcih groups where different from each other (unlike a standard ANOVA test). It also ensured against incorrectly rejecting the null hypothesis by performing multiple tests (through controls).

# %% [markdown]
# ## **Considerations**
#
# **What are some key takeaways that you learned during this lab?**
#
# I learnt how to explore and clean data, how to build a linear regression model, check model assumptions, analyse model results, perform a one-way ANOVA test and also perform an ANOVA post hoc test.
#
#
# **What summary would you provide to stakeholders? Consider the statistical significance of key relationships and differences in distribution.**
#
# Different TV advertising spent contributed to a difference in sales generated with an almost certain probability.

# %% [markdown]
# #### **Reference**
# [Saragih, H.S. *Dummy Marketing and Sales Data*](https://www.kaggle.com/datasets/harrimansaragih/dummy-advertising-and-sales-data)

# %% [markdown]
# **Congratulations!** You've completed this lab. However, you may not notice a green check mark next to this item on Coursera's platform. Please continue your progress regardless of the check mark. Just click on the "save" icon at the top of this notebook to ensure your work has been logged.
